# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
import pandas as pd

# Load Iris dataset
data = load_iris()
X = data.data
y = data.target
target_names = data.target_names

# Perform PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
print("Explained variance ratio:", pca.explained_variance_ratio_)

# Plot PCA results
colors = ['navy', 'turquoise', 'darkorange']
for i, target in enumerate([0, 1, 2]):
    plt.scatter(X_pca[y == target, 0], X_pca[y == target, 1],
                color=colors[i], label=target_names[i], edgecolor='k')

plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.title('PCA of IRIS Dataset (from sklearn)')
plt.legend()
plt.show()
# Out:
# Explained variance ratio: [0.92461872 0.05306648]

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Load dataset
df = pd.read_csv(r'C:\Users\Admin\Documents\ML_Lab\iris.csv')
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# Features and labels
X = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = df['species']

# PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

print("Explained variance ratio:", pca.explained_variance_ratio_)

# Correct color mapping
colors = {
    'setosa': 'navy',
    'versicolor': 'turquoise',
    'virginica': 'darkorange'
}

# Plot
for species in df['species'].unique():
    mask = (y == species)
    plt.scatter(X_pca[mask, 0], X_pca[mask, 1],
                color=colors[species], label=species, edgecolor='k')

plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.title('PCA of IRIS Dataset')
plt.legend()
plt.show()
# Out:
# Explained variance ratio: [0.92461872 0.05306648]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Load iris data from local CSV file (update the file path as needed)
df = pd.read_csv(r'C:\Users\Admin\Documents\ML_Lab\iris.csv')

# If your CSV file doesn't have column headers, uncomment the following line and set the column names:
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# Extract features and labels
X = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = df['species']

# Create a PCA instance: reduce dimensions from 4 to 2
pca = PCA(n_components=2)
X_r = pca.fit_transform(X)

# Print the explained variance ratio to see the contribution of each component
print("Explained variance ratio:", pca.explained_variance_ratio_)

# Define colors for different species (adjust keys based on your CSV content)
colors = {'Iris-setosa': 'navy', 'Iris-versicolor': 'turquoise', 'Iris-virginica': 'darkorange'}

# Plot the PCA result
plt.figure(figsize=(8, 6))
for species in df['species'].unique():
    idx = df['species'] == species
    plt.scatter(X_r[idx, 0], X_r[idx, 1], c=colors.get(species),     label=species, edgecolor='k', s=50)

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of IRIS Dataset')
plt.legend(loc='best')
plt.grid(True)
plt.show()
# Out:
# Explained variance ratio: [0.92461872 0.05306648]

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

df=pd.read_csv(r"iris.csv")

df.columns=['sepal_width','sepal_length','petal_width','petal_length','species']

x=df[['sepal_width','sepal_length','petal_width','petal_length']]
y=df['species']

pca=PCA(n_components=2)
X_r=pca.fit_transform(x)

print("\nExplained Variance Ratio ",pca.explained_variance_ratio_)

colors = {'Iris-setosa': 'navy', 'Iris-versicolor': 'turquoise', 'Iris-virginica': 'darkorange'}

plt.figure(figsize=(8, 6))
for species in df['species'].unique():
    idx = df['species'] == species
    plt.scatter(X_r[idx, 0], X_r[idx, 1],c=colors.get(species),label=species,edgecolors='k',s=50)

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of IRIS Dataset')
plt.legend(loc='best')
plt.grid(True)
plt.show()
# Out:
# Explained Variance Ratio  [0.92461872 0.05306648]

# %%
import pandas as pd
from sklearn.decomposition import PCA

# %%
import matplotlib.pyplot as plt

data=pd.read_csv(r'iris.csv')

data.columns=['sepal_width','sepal_length','petal_width','petal_length','species']

x=data[['sepal_width','sepal_length','petal_width','petal_length']]
y=data['species']

pca=PCA(n_components=2)
X_pca=pca.fit_transform(x)

print("Explained Variance Ratio:",pca.explained_variance_ratio_)

colors={'Iris-setosa':'navy','Iris-versicolor':'turquoise','Iris-virginica':'darkorange'}

plt.figure(figsize=(8,6))
for species in data['species'].unique():
    idx= data['species'] == species
    plt.scatter(X_pca[idx, 0],X_pca[idx,1],c=colors.get(species),label=species,edgecolors='k',s=50)

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of IRIS Dataset')
plt.legend(loc='best')
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# Explained Variance Ratio: [0.92461872 0.05306648]
