# %%
#Import all the necessary libraries
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.datasets import fetch_california_housing

# Load the California Housing Dataset
#housing = fetch_california_housing(as_frame=True)
#df = housing.frame

# Read the CSV file into a DataFrame
df = pd.read_csv(r"housing.csv")

# Create Histograms for All Numerical Features
df.hist(bins=30, figsize=(15, 10))
plt.suptitle("Histograms of California Housing Features",y=1.02)
plt.show()
#plt.savefig("histograms.jpeg")  # Save the figure
plt.close()

# Create a Combined Boxplot for All Features
plt.figure(figsize=(12, 8))
sns.boxplot(data=df)
plt.title("Boxplot of California Housing Features")
plt.xlabel("Features")
plt.ylabel("Value")
plt.show()
#plt.savefig("boxplot.jpeg")
plt.close()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_california_housing
import pandas as pd

df=pd.read_csv(r'housing.csv')

df.hist(bins=30,figsize=(15,10))
plt.suptitle("Histogram of Features of California Housing Dataset",y=1.02)
plt.show()
plt.close()

plt.figure(figsize=(15,10))
sns.boxplot(data=df)
plt.title("Boxplot of CHD")
plt.xlabel("Features")
plt.ylabel("Values")
plt.show()
plt.close()
